# %%
import gymnasium as gym

from stable_baselines3 import DQN
from stable_baselines3.common.evaluation import evaluate_policy


# Create environment
env = gym.make("LunarLander-v2", render_mode="rgb_array")

# Instantiate the agent
model = DQN("MlpPolicy", env, verbose=1)
# Train the agent and display a progress bar
model.learn(total_timesteps=int(2e5), progress_bar=True)
# Save the agent
model.save("dqn_lunar")
del model  # delete trained model to demonstrate loading

# Load the trained agent
# NOTE: if you have loading issue, you can pass `print_system_info=True`
# to compare the system on which the model was trained vs the current one
# model = DQN.load("dqn_lunar", env=env, print_system_info=True)
model = DQN.load("dqn_lunar", env=env)

# Evaluate the agent
# NOTE: If you use wrappers with your environment that modify rewards,
#       this will be reflected here. To evaluate with original rewards,
#       wrap environment in a "Monitor" wrapper before other wrappers.
mean_reward, std_reward = evaluate_policy(model, model.get_env(), n_eval_episodes=10)
# Out:
# Output()
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 118      |
# |    ep_rew_mean      | -132     |
# |    exploration_rate | 0.978    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1998     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 470      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.31     |
# |    n_updates        | 92       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 109      |
# |    ep_rew_mean      | -206     |
# |    exploration_rate | 0.958    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 2070     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 875      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.38     |
# |    n_updates        | 193      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 107      |
# |    ep_rew_mean      | -208     |
# |    exploration_rate | 0.939    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 2082     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1281     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.41     |
# |    n_updates        | 295      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 103      |
# |    ep_rew_mean      | -223     |
# |    exploration_rate | 0.922    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 2070     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1651     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.13     |
# |    n_updates        | 387      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 103      |
# |    ep_rew_mean      | -228     |
# |    exploration_rate | 0.902    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 2080     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2054     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.19     |
# |    n_updates        | 488      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -224     |
# |    exploration_rate | 0.884    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 2080     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2441     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.27     |
# |    n_updates        | 585      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -228     |
# |    exploration_rate | 0.864    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 2079     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2863     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.913    |
# |    n_updates        | 690      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -221     |
# |    exploration_rate | 0.846    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 2083     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3239     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.22     |
# |    n_updates        | 784      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 103      |
# |    ep_rew_mean      | -215     |
# |    exploration_rate | 0.824    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 2073     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3705     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.995    |
# |    n_updates        | 901      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -205     |
# |    exploration_rate | 0.806    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 2080     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4089     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.979    |
# |    n_updates        | 997      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 107      |
# |    ep_rew_mean      | -204     |
# |    exploration_rate | 0.777    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 2074     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4688     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.03     |
# |    n_updates        | 1146     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 110      |
# |    ep_rew_mean      | -209     |
# |    exploration_rate | 0.75     |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 2058     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 5264     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.06     |
# |    n_updates        | 1290     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | -202     |
# |    exploration_rate | 0.72     |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 2039     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 5898     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.91     |
# |    n_updates        | 1449     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 115      |
# |    ep_rew_mean      | -199     |
# |    exploration_rate | 0.693    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 2012     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 6462     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.31     |
# |    n_updates        | 1590     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 117      |
# |    ep_rew_mean      | -201     |
# |    exploration_rate | 0.666    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 2004     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 7028     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.81     |
# |    n_updates        | 1731     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 119      |
# |    ep_rew_mean      | -195     |
# |    exploration_rate | 0.637    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 1996     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 7639     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.92     |
# |    n_updates        | 1884     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 123      |
# |    ep_rew_mean      | -190     |
# |    exploration_rate | 0.604    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 1971     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 8335     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.595    |
# |    n_updates        | 2058     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 125      |
# |    ep_rew_mean      | -187     |
# |    exploration_rate | 0.571    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 1946     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 9022     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.54     |
# |    n_updates        | 2230     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 129      |
# |    ep_rew_mean      | -185     |
# |    exploration_rate | 0.533    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 1924     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 9834     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.848    |
# |    n_updates        | 2433     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 132      |
# |    ep_rew_mean      | -182     |
# |    exploration_rate | 0.5      |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 1904     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 10532    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.28     |
# |    n_updates        | 2607     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 138      |
# |    ep_rew_mean      | -180     |
# |    exploration_rate | 0.449    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 1853     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 11603    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.818    |
# |    n_updates        | 2875     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 154      |
# |    ep_rew_mean      | -179     |
# |    exploration_rate | 0.356    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 1643     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 13555    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.879    |
# |    n_updates        | 3363     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 169      |
# |    ep_rew_mean      | -182     |
# |    exploration_rate | 0.263    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 1544     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 15516    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.933    |
# |    n_updates        | 3853     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 203      |
# |    ep_rew_mean      | -179     |
# |    exploration_rate | 0.073    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 1298     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 19516    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.27     |
# |    n_updates        | 4853     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 235      |
# |    ep_rew_mean      | -176     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 1131     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 23516    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.774    |
# |    n_updates        | 5853     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 236      |
# |    ep_rew_mean      | -183     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 1138     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 24094    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.817    |
# |    n_updates        | 5998     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 248      |
# |    ep_rew_mean      | -189     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 1111     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 25643    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.55     |
# |    n_updates        | 6385     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 268      |
# |    ep_rew_mean      | -192     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 1073     |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 28048    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.808    |
# |    n_updates        | 6986     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 287      |
# |    ep_rew_mean      | -192     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 1043     |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 30314    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.781    |
# |    n_updates        | 7553     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 290      |
# |    ep_rew_mean      | -197     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 1049     |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 31066    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.96     |
# |    n_updates        | 7741     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 302      |
# |    ep_rew_mean      | -197     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 1042     |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 32611    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.832    |
# |    n_updates        | 8127     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 330      |
# |    ep_rew_mean      | -194     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 1006     |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 35861    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.707    |
# |    n_updates        | 8940     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 342      |
# |    ep_rew_mean      | -194     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 1002     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 37418    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.561    |
# |    n_updates        | 9329     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 371      |
# |    ep_rew_mean      | -195     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 974      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 40841    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.53     |
# |    n_updates        | 10185    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 398      |
# |    ep_rew_mean      | -197     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 956      |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 43859    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.458    |
# |    n_updates        | 10939    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 423      |
# |    ep_rew_mean      | -192     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 949      |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 47030    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.819    |
# |    n_updates        | 11732    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 450      |
# |    ep_rew_mean      | -178     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 932      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 50308    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.67     |
# |    n_updates        | 12551    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 477      |
# |    ep_rew_mean      | -176     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 923      |
# |    time_elapsed     | 57       |
# |    total_timesteps  | 53570    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.872    |
# |    n_updates        | 13367    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 511      |
# |    ep_rew_mean      | -170     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 911      |
# |    time_elapsed     | 63       |
# |    total_timesteps  | 57570    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.538    |
# |    n_updates        | 14367    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 535      |
# |    ep_rew_mean      | -164     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 909      |
# |    time_elapsed     | 66       |
# |    total_timesteps  | 60490    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.724    |
# |    n_updates        | 15097    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 562      |
# |    ep_rew_mean      | -160     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 905      |
# |    time_elapsed     | 70       |
# |    total_timesteps  | 63790    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.513    |
# |    n_updates        | 15922    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 585      |
# |    ep_rew_mean      | -158     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 900      |
# |    time_elapsed     | 74       |
# |    total_timesteps  | 66857    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.69     |
# |    n_updates        | 16689    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 611      |
# |    ep_rew_mean      | -153     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 897      |
# |    time_elapsed     | 78       |
# |    total_timesteps  | 70140    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.731    |
# |    n_updates        | 17509    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 625      |
# |    ep_rew_mean      | -157     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 903      |
# |    time_elapsed     | 80       |
# |    total_timesteps  | 72364    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.573    |
# |    n_updates        | 18065    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 639      |
# |    ep_rew_mean      | -156     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 906      |
# |    time_elapsed     | 82       |
# |    total_timesteps  | 74473    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.49     |
# |    n_updates        | 18593    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 660      |
# |    ep_rew_mean      | -149     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 906      |
# |    time_elapsed     | 85       |
# |    total_timesteps  | 77587    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.592    |
# |    n_updates        | 19371    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 667      |
# |    ep_rew_mean      | -144     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 905      |
# |    time_elapsed     | 88       |
# |    total_timesteps  | 80212    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.743    |
# |    n_updates        | 20027    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 679      |
# |    ep_rew_mean      | -130     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 903      |
# |    time_elapsed     | 92       |
# |    total_timesteps  | 83426    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.488    |
# |    n_updates        | 20831    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 671      |
# |    ep_rew_mean      | -125     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 899      |
# |    time_elapsed     | 96       |
# |    total_timesteps  | 86597    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.69     |
# |    n_updates        | 21624    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 660      |
# |    ep_rew_mean      | -128     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 892      |
# |    time_elapsed     | 100      |
# |    total_timesteps  | 89485    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.97     |
# |    n_updates        | 22346    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 679      |
# |    ep_rew_mean      | -114     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 892      |
# |    time_elapsed     | 103      |
# |    total_timesteps  | 92022    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.854    |
# |    n_updates        | 22980    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 694      |
# |    ep_rew_mean      | -99      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 893      |
# |    time_elapsed     | 106      |
# |    total_timesteps  | 95060    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.54     |
# |    n_updates        | 23739    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 692      |
# |    ep_rew_mean      | -88.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 891      |
# |    time_elapsed     | 109      |
# |    total_timesteps  | 97282    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.615    |
# |    n_updates        | 24295    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 689      |
# |    ep_rew_mean      | -75.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 893      |
# |    time_elapsed     | 111      |
# |    total_timesteps  | 99244    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.632    |
# |    n_updates        | 24785    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 718      |
# |    ep_rew_mean      | -58.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 885      |
# |    time_elapsed     | 116      |
# |    total_timesteps  | 102881   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.547    |
# |    n_updates        | 25695    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 729      |
# |    ep_rew_mean      | -56.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 883      |
# |    time_elapsed     | 119      |
# |    total_timesteps  | 105476   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.968    |
# |    n_updates        | 26343    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 727      |
# |    ep_rew_mean      | -53      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 887      |
# |    time_elapsed     | 122      |
# |    total_timesteps  | 108531   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.754    |
# |    n_updates        | 27107    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 744      |
# |    ep_rew_mean      | -46.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 880      |
# |    time_elapsed     | 127      |
# |    total_timesteps  | 111829   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.919    |
# |    n_updates        | 27932    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 745      |
# |    ep_rew_mean      | -39.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 873      |
# |    time_elapsed     | 132      |
# |    total_timesteps  | 115390   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.508    |
# |    n_updates        | 28822    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 741      |
# |    ep_rew_mean      | -40.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 871      |
# |    time_elapsed     | 135      |
# |    total_timesteps  | 117990   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.947    |
# |    n_updates        | 29472    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 745      |
# |    ep_rew_mean      | -39.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 867      |
# |    time_elapsed     | 140      |
# |    total_timesteps  | 121530   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.51     |
# |    n_updates        | 30357    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 739      |
# |    ep_rew_mean      | -40.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 865      |
# |    time_elapsed     | 143      |
# |    total_timesteps  | 124237   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.05     |
# |    n_updates        | 31034    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 743      |
# |    ep_rew_mean      | -42.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 860      |
# |    time_elapsed     | 148      |
# |    total_timesteps  | 127832   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.971    |
# |    n_updates        | 31932    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 743      |
# |    ep_rew_mean      | -42.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 853      |
# |    time_elapsed     | 154      |
# |    total_timesteps  | 131832   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.647    |
# |    n_updates        | 32932    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 739      |
# |    ep_rew_mean      | -45.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 853      |
# |    time_elapsed     | 157      |
# |    total_timesteps  | 134399   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.93     |
# |    n_updates        | 33574    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 744      |
# |    ep_rew_mean      | -45.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 849      |
# |    time_elapsed     | 162      |
# |    total_timesteps  | 138187   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.908    |
# |    n_updates        | 34521    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 747      |
# |    ep_rew_mean      | -45      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 845      |
# |    time_elapsed     | 167      |
# |    total_timesteps  | 141552   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.478    |
# |    n_updates        | 35362    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 754      |
# |    ep_rew_mean      | -47.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 843      |
# |    time_elapsed     | 172      |
# |    total_timesteps  | 145552   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.86     |
# |    n_updates        | 36362    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 772      |
# |    ep_rew_mean      | -41.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 843      |
# |    time_elapsed     | 177      |
# |    total_timesteps  | 149552   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1        |
# |    n_updates        | 37362    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 791      |
# |    ep_rew_mean      | -40.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 841      |
# |    time_elapsed     | 182      |
# |    total_timesteps  | 153552   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.59     |
# |    n_updates        | 38362    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 800      |
# |    ep_rew_mean      | -45.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 836      |
# |    time_elapsed     | 188      |
# |    total_timesteps  | 157552   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.533    |
# |    n_updates        | 39362    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 813      |
# |    ep_rew_mean      | -48.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 832      |
# |    time_elapsed     | 194      |
# |    total_timesteps  | 161552   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.761    |
# |    n_updates        | 40362    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 821      |
# |    ep_rew_mean      | -57.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 826      |
# |    time_elapsed     | 200      |
# |    total_timesteps  | 165552   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.934    |
# |    n_updates        | 41362    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 830      |
# |    ep_rew_mean      | -60.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 817      |
# |    time_elapsed     | 207      |
# |    total_timesteps  | 169552   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.7      |
# |    n_updates        | 42362    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 841      |
# |    ep_rew_mean      | -54.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 814      |
# |    time_elapsed     | 213      |
# |    total_timesteps  | 173551   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.859    |
# |    n_updates        | 43362    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 855      |
# |    ep_rew_mean      | -58.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 810      |
# |    time_elapsed     | 218      |
# |    total_timesteps  | 177551   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.687    |
# |    n_updates        | 44362    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 865      |
# |    ep_rew_mean      | -62.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 806      |
# |    time_elapsed     | 225      |
# |    total_timesteps  | 181551   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.577    |
# |    n_updates        | 45362    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 883      |
# |    ep_rew_mean      | -64      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 803      |
# |    time_elapsed     | 230      |
# |    total_timesteps  | 185551   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.643    |
# |    n_updates        | 46362    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 903      |
# |    ep_rew_mean      | -67.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 804      |
# |    time_elapsed     | 235      |
# |    total_timesteps  | 189551   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.905    |
# |    n_updates        | 47362    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 907      |
# |    ep_rew_mean      | -74.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 802      |
# |    time_elapsed     | 241      |
# |    total_timesteps  | 193551   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.498    |
# |    n_updates        | 48362    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 921      |
# |    ep_rew_mean      | -72.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 800      |
# |    time_elapsed     | 246      |
# |    total_timesteps  | 197551   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.535    |
# |    n_updates        | 49362    |
# ----------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
# Enjoy trained agent
vec_env = model.get_env()
obs = vec_env.reset()
for i in range(1000):
    action, _states = model.predict(obs, deterministic=True)
    obs, rewards, dones, info = vec_env.step(action)
    vec_env.render("human")

# %%
vec_env = model.get_env()
obs = vec_env.reset()
for i in range(1000):
    action, _state = model.predict(obs, deterministic=True)
    obs, reward, done, info = vec_env.step(action)
    vec_env.render("human")
